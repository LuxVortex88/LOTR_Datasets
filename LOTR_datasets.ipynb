# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

books_LOTR = ["The Fellowship of the Ring", "The Two Towers", "The Return of the King"]

ranking = [1, 2, 3]

print(books_LOTR)
print(ranking)

plt.barh(books_LOTR, ranking)
plt.show()
# Out:
# ['The Fellowship of the Ring', 'The Two Towers', 'The Return of the King']
# [1, 2, 3]
